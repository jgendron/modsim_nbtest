# %%
'''
Purpose:
Extract parameters about all MODSIM papers published from 2014 to 2018
Transform parameters within a dataframe
Load the text of the MODSIM papers into a working data set

Inputs:
The inputs for this procedure include:
* A list of MODSIM websites containing the papers for parsing HTML with BeautifulSoup
* Text files containing full text from each MODSIM Papers (2014 to 2018)
  ** Downloaded PDF from MODSIM website using Google Chrono Sniffer extension
  ** Converted to text using Mac OS Automator workflow
  ** Assumes a file structure ./data/<year>/ exists for years 2014-2018

Output:
The results of this module is a folder called ./data/abstracts/ containing .txt files each with a custom label and containing abstracts extracted from MODSIM papers.
'''

import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# Provide list of all sites containing MODSIM Papers 2014-2018
sites = ['http://modsimworld.org/conference-papers/2014',
         'http://modsimworld.org/conference-papers/2015',
         'http://modsimworld.org/conference-papers/2016',
         'http://modsimworld.org/conference-papers/2017',
         'http://modsimworld.org/conference-papers/2018']
# Create an empty list to capture webscrape results 
records = [] 

# Extract: get parameters of papers into a dataframe
for site in sites:
    page = requests.get(site)
    soup = BeautifulSoup(page.text, 'html.parser')
    results = soup.find_all('table') # finds all tables on page, each is a track

    for result in results:
        for r in result.findAll('tr'):
            if r.find('td') is not None:
                track = result.find('th').text
                filename = r.find('a')['href'][13:]
                author = r.find('td').text
                title = r.find('span').text
                year = r.find('a')['href'][8:12]
                records.append((track,filename,author,title,year))

df = pd.DataFrame(records, columns = ['track', 'filename', 'author_id', 'title', 'year'])

# Transform: relabel tracks into one of four categories
df['year'] = df['year'].apply(str)
mapped_sub = {'track': {'Training and Education': 'TE',
                        'Training': 'TE',
                        'Eduction': 'TE',
                        'Analytics and Decision Making': 'AT',
                        'Analytics and Decision-Making': 'AT',
                        'Science and Engineering': 'SE',
                        'Visualization and Gamification': 'VG',
                        'Entertainment, Sports, Media, & Visualization': 'VG',
                        'Cyber Security': 'VG'}
             }
df_mod = df.replace(to_replace=mapped_sub)

# Transform: convert .pdf filenames into .txt
df_mod['filename'] = df_mod['filename'].str.replace('pdf', 'txt')

# Transform: extract first occurence of last name as author tag
# create three individual series for three types of matches
a=df_mod['author_id'].str.extract(r'([a-zA-Z]+,)')
b=df_mod['author_id'].str.extract(r'([a-zA-Z]+ and)')
c=df_mod['author_id'].str.extract(r'([a-zA-Z]+$)')

# combine the three temp series with precedence for already filled rows
temp = a.combine_first(b).combine_first(c)
# remove the separator flags 
temp[0] = temp[0].str.replace(',','') # a series function
temp[0] = temp[0].str.replace('and','')
df_mod['author_id'] = temp[0]

# Create doc labels in track-year-author format  
df_mod['label'] = './data/abstracts/' + df_mod['track'] + '-' + \
                df_mod['year'] + '-' + df_mod['author_id'] + '.txt'
df_mod
# Out:
#          track                                           filename  \
# 0           AT  MS1401-Pratical HSI Methods for Medical Simula...
# 1           AT       MS1480-Decision Making MODSIM 2014 Paper.txt
# 2           AT  MODSIM2014_MIST_INSPYRED_Paper_Submit_2014_03_...
# 3           AT                              SCDT_MODSIM Paper.txt
# 4           AT  MS1470_MODSIM_2014_Massed Exposure Improves Re...
# 5           AT  2013 Virginia Homeland Security Portfolio Valu...
# 6           AT                             MODSIM2014_LVCGAED.txt
# 7           AT           SpecializedTankInspectionandOverhaul.txt
# 8           AT               Equal but Different_20140312_SJL.txt
# 9           AT  Final Energy Resilience MODSIM 2014 Paper_14 M...
# 10   Education  MODSIM_World_2014_CoL_ Fautua Schatz et al 16M...
# 11   Education  MS1421-Knowledge Quest (Gendron and Friedman).txt
# 12   Education                            1484_Hulme_04042014.txt
# 13   Education  MODSIM_World_2014_Schatz_Colombo_Graffeo_Bolto...
# 14   Education  MODSIM World 2014 Paper number 1478 April 7 20...
# 15   Education                     2014 - Modsim - VOR-zFinal.txt
# 16          VG                           MODSIM collins paper.txt
# 17          VG              AIMS_ModSim_Paper_2014CawrseFinal.txt
# 18          VG                             Modsim2014_Paperv3.txt
# 19          VG             MODSIM_World_2014_Lenuik_Murley_v2.txt
# 20          SE                                    SIVL_MODSIM.txt
# 21          SE   ModSimWorld_2014_Mook_ManufacturingSim_Final.txt
# 22          SE               Lin_Watson_MODSim2014_Submitted2.txt
# 23          SE  MODSIM World 2014 Riverscout_Jesse_Barboza 041...
# 24          SE             Lackey_Badillo-Urquiola_Ortiz_1475.txt
# 25          SE                 INS Modsim World Paper - Final.txt
# 26          SE                         MODSIMWorld-2014-1964C.txt
# 27          SE  MODSIM World 2014 Developing an Ultrasonograph...
# 28          SE                    1472_MITLincolnLabs_MSW2014.txt
# 29          TE  Utilizing Real Test Sets on Maintenance Traini...
# ..         ...                                                ...
# 178         SE        MODSIM_2018_Paper_not_required_for_a_10.txt
# 179         SE        MODSIM_2018_Paper_not_required_for_a_14.txt
# 180         SE        MODSIM_2018_Paper_not_required_for_a_19.txt
# 181         SE        MODSIM_2018_Paper_not_required_for_a_26.txt
# 182         SE        MODSIM_2018_Paper_not_required_for_a_35.txt
# 183         SE        MODSIM_2018_Paper_not_required_for_a_36.txt
# 184         SE        MODSIM_2018_Paper_not_required_for_a_52.txt
# 185         SE        MODSIM_2018_Paper_not_required_for_a_55.txt
# 186         SE        MODSIM_2018_Paper_not_required_for_a_56.txt
# 187         TE         MODSIM_2018_Paper_not_required_for_a_7.txt
# 188         TE        MODSIM_2018_Paper_not_required_for_a_15.txt
# 189         TE        MODSIM_2018_Paper_not_required_for_a_17.txt
# 190         TE        MODSIM_2018_Paper_not_required_for_a_18.txt
# 191         TE        MODSIM_2018_Paper_not_required_for_a_22.txt
# 192         TE        MODSIM_2018_Paper_not_required_for_a_23.txt
# 193         TE        MODSIM_2018_Paper_not_required_for_a_24.txt
# 194         TE        MODSIM_2018_Paper_not_required_for_a_29.txt
# 195         TE        MODSIM_2018_Paper_not_required_for_a_43.txt
# 196         TE        MODSIM_2018_Paper_not_required_for_a_44.txt
# 197         TE        MODSIM_2018_Paper_not_required_for_a_50.txt
# 198         TE        MODSIM_2018_Paper_not_required_for_a_65.txt
# 199         TE        MODSIM_2018_Paper_not_required_for_a_66.txt
# 200         VG         MODSIM_2018_Paper_not_required_for_a_2.txt
# 201         VG        MODSIM_2018_Paper_not_required_for_a_28.txt
# 202         VG        MODSIM_2018_Paper_not_required_for_a_30.txt
# 203         VG        MODSIM_2018_Paper_not_required_for_a_31.txt
# 204         VG        MODSIM_2018_Paper_not_required_for_a_48.txt
# 205         VG        MODSIM_2018_Paper_not_required_for_a_53.txt
# 206         VG        MODSIM_2018_Paper_not_required_for_a_59.txt
# 207         VG        MODSIM_2018_Paper_not_required_for_a_63.txt
#
#          author_id                                              title  year  \
# 0        Bockelman  Practical Human-Systems Integration Methods fo...  2014
# 1             Hase  Evidence Based Decision Making: Techniques for...  2014
# 2          Barhak   Population Generation from Statistics Using Ge...  2014
# 3            Allen  Discrete Event Simulation for Supporting Produ...  2014
# 4           Lackey  Massed Exposure Improves Response Time for Det...  2014
# 5           Ezell   2013 Virginia Homeland Security Portfolio Valu...  2014
# 6             Brun  The Assisted Experimental Designer: A Decision...  2014
# 7         Drucker   An Adaptive Planning Tool For Air Craft Carrie...  2014
# 8           Lackey  Equal but Different: 5 Research Strategies for...  2014
# 9          Delaney  Resilience: Modeling for Conditions of Uncerta...  2014
# 10       Bockelman  Enhancing Joint Training through Blended Learn...  2014
# 11       Friedman   The Quest for Knowledge: How MOOCs Provide Ins...  2014
# 12         Fabiano  Game-oriented Technology and Simulation to re-...  2014
# 13          Bolton  On Developing a Taxonomy of Perceptual–Cogniti...  2014
# 14         Rosacia  Source Selection Process Improvement and Workf...  2014
# 15           Croll  Behavior Authoring and Run-time Management of ...  2014
# 16            Ball   Exploring the "Whys" of Simulation Visualization  2014
# 17         Cawrse   AIMSTM Computational Challenges - Computationa...  2014
# 18            Aras  Point-based Methods for Medical Modeling and S...  2014
# 19         Lenuik   Building a Framework to Support Platform Indep...  2014
# 20       Buttrill   UAS-Systems Integration, Validation, and Diagn...  2014
# 21            Mook  Developing a Manufacturing Simulation as a Del...  2014
# 22            Lin   A Pilot Study Investigating College Students M...  2014
# 23         Barboza  Conversion Challenges of an Autonomous Maritim...  2014
# 24        Urquiola  Research-Driven Recommendations for Implementi...  2014
# 25           Croll  Modeling and Simulation of Inertial Navigation...  2014
# 26           Heath  Automated User Interface Generation for Dynami...  2014
# 27           Banks  Developing an Ultrasonography Simulator Traini...  2014
# 28          Carter  Adaptive Attacker Strategy Development Against...  2014
# 29         Ferrell  Utilizing Real Test Sets on Maintenance Traini...  2014
# ..             ...                                                ...   ...
# 178        Seasly   Preventing Premature Death in the M&S Lifecycl...  2018
# 179         Daiker  Use of Real-Time, Predictive Human Modeling fo...  2018
# 180       Griffith  A Multi-level Universal Specification ofr Inte...  2018
# 181      Aureliano  IoT Applied to the Control and Monitoring in S...  2018
# 182        Watson   Modeling of the Ionosphere Reveals Wide Bandwi...  2018
# 183         Dauble  Leveraging Commercial Game Engine for Multi-Do...  2018
# 184       Kaimakis  Domain-Specific Reduction of Language Model Da...  2018
# 185       Franklin  Simulation Based Optimization of a Propulsion ...  2018
# 186          Burns  Systems Engineering: Optimizing Creation of Vi...  2018
# 187           Bell  A "Stories-as-aService" Architecture for Enric...  2018
# 188        Freeman  Existential correlation of system complexity a...  2018
# 189         Wismer  Assessing Performance and Usability of 3D Visu...  2018
# 190      Puskaritz  Enhancing Trainee Immersion with Goal_Directed...  2018
# 191        Babcock  Ready, Aim, Perform! Targeted Micro-Training f...  2018
# 192        Reardon  Evolution of Green Pig: Best Practices in Mobi...  2018
# 193          Dunne  Validating Simulators for Live, Virtual, Const...  2018
# 194            Joe  The challenge of designing instructionally sou...  2018
# 195        Goodwin  A taxonomy for the Evaluation of Training Simu...  2018
# 196          Dupre  Training for Operations in a Contested Space D...  2018
# 197          Davis  Critical Thinking Training: Proven New Technol...  2018
# 198        Klafehn  Walking a Mile in Simulated Shoes: Development...  2018
# 199          Kiehl  An Immersive Approach to Providing Mishap Awar...  2018
# 200           Swan  Visualizaing and Simulating on Whole World Ter...  2018
# 201        Maxwell  Evaluating the Applicability of Repurposed Ent...  2018
# 202        Hackett  Technology Acceptance of a Virtual Tactical Co...  2018
# 203       Leathrum  Integrating Virtual and Augmented Reality Base...  2018
# 204        Bucioli  Automated Generation of Holographic Heart Visu...  2018
# 205  Renduchintala  Child-Centric Interactive Exercise Devices (CC...  2018
# 206         Tracey  Visualization of the Process Interaction World...  2018
# 207         Lackey  Graphical Representations Provide Insight into...  2018
#
#                                              label
# 0           ./data/abstracts/AT-2014-Bockelman.txt
# 1                ./data/abstracts/AT-2014-Hase.txt
# 2             ./data/abstracts/AT-2014-Barhak .txt
# 3               ./data/abstracts/AT-2014-Allen.txt
# 4              ./data/abstracts/AT-2014-Lackey.txt
# 5              ./data/abstracts/AT-2014-Ezell .txt
# 6                ./data/abstracts/AT-2014-Brun.txt
# 7            ./data/abstracts/AT-2014-Drucker .txt
# 8              ./data/abstracts/AT-2014-Lackey.txt
# 9             ./data/abstracts/AT-2014-Delaney.txt
# 10   ./data/abstracts/Education-2014-Bockelman.txt
# 11   ./data/abstracts/Education-2014-Friedman .txt
# 12     ./data/abstracts/Education-2014-Fabiano.txt
# 13      ./data/abstracts/Education-2014-Bolton.txt
# 14     ./data/abstracts/Education-2014-Rosacia.txt
# 15       ./data/abstracts/Education-2014-Croll.txt
# 16               ./data/abstracts/VG-2014-Ball.txt
# 17            ./data/abstracts/VG-2014-Cawrse .txt
# 18               ./data/abstracts/VG-2014-Aras.txt
# 19            ./data/abstracts/VG-2014-Lenuik .txt
# 20          ./data/abstracts/SE-2014-Buttrill .txt
# 21               ./data/abstracts/SE-2014-Mook.txt
# 22               ./data/abstracts/SE-2014-Lin .txt
# 23            ./data/abstracts/SE-2014-Barboza.txt
# 24           ./data/abstracts/SE-2014-Urquiola.txt
# 25              ./data/abstracts/SE-2014-Croll.txt
# 26              ./data/abstracts/SE-2014-Heath.txt
# 27              ./data/abstracts/SE-2014-Banks.txt
# 28             ./data/abstracts/SE-2014-Carter.txt
# 29            ./data/abstracts/TE-2014-Ferrell.txt
# ..                                             ...
# 178           ./data/abstracts/SE-2018-Seasly .txt
# 179            ./data/abstracts/SE-2018-Daiker.txt
# 180          ./data/abstracts/SE-2018-Griffith.txt
# 181         ./data/abstracts/SE-2018-Aureliano.txt
# 182           ./data/abstracts/SE-2018-Watson .txt
# 183            ./data/abstracts/SE-2018-Dauble.txt
# 184          ./data/abstracts/SE-2018-Kaimakis.txt
# 185          ./data/abstracts/SE-2018-Franklin.txt
# 186             ./data/abstracts/SE-2018-Burns.txt
# 187              ./data/abstracts/TE-2018-Bell.txt
# 188           ./data/abstracts/TE-2018-Freeman.txt
# 189            ./data/abstracts/TE-2018-Wismer.txt
# 190         ./data/abstracts/TE-2018-Puskaritz.txt
# 191           ./data/abstracts/TE-2018-Babcock.txt
# 192           ./data/abstracts/TE-2018-Reardon.txt
# 193             ./data/abstracts/TE-2018-Dunne.txt
# 194               ./data/abstracts/TE-2018-Joe.txt
# 195           ./data/abstracts/TE-2018-Goodwin.txt
# 196             ./data/abstracts/TE-2018-Dupre.txt
# 197             ./data/abstracts/TE-2018-Davis.txt
# 198           ./data/abstracts/TE-2018-Klafehn.txt
# 199             ./data/abstracts/TE-2018-Kiehl.txt
# 200              ./data/abstracts/VG-2018-Swan.txt
# 201           ./data/abstracts/VG-2018-Maxwell.txt
# 202           ./data/abstracts/VG-2018-Hackett.txt
# 203          ./data/abstracts/VG-2018-Leathrum.txt
# 204           ./data/abstracts/VG-2018-Bucioli.txt
# 205     ./data/abstracts/VG-2018-Renduchintala.txt
# 206            ./data/abstracts/VG-2018-Tracey.txt
# 207            ./data/abstracts/VG-2018-Lackey.txt
#
# [208 rows x 6 columns]
